# %%
import pandas as pd
from graph_generator import GraphGenerator


precision_path = 'categorical_precision.pdf'
recall_path = 'categorical_recall.pdf'
time_path = 'categorical_time.pdf'

graph_data = pd.read_csv('montage.csv', float_precision='round_trip', sep=',')
graph_data.sample(750)
# print(graph_data)
# graph_generator = GraphGenerator()
# graph_generator.bar_graph(graph_data, precision_path, "K", "PRECISION", "MODEL", "PRECISION")
# graph_generator.bar_graph(graph_data, recall_path, "K", "RECALL", "MODEL", "RECALL")
# graph_generator.bar_graph(graph_data, time_path, "K", "TIME", "MODEL", "TIME")

# precision_path = 'exp0/montage/categorical_precision.pdf'
# recall_path = 'exp0/montage/categorical_recall.pdf'
# time_path = 'exp0/montage/categorical_time.pdf'

# graph_data = pd.read_csv('exp0/montage/original.csv', float_precision='round_trip', sep=';')
# graph_generator = GraphGenerator()
# graph_generator.bar_graph(graph_data, precision_path, "FEATURE", "PRECISION", "MODEL", "PRECISION")
# graph_generator.bar_graph(graph_data, recall_path, "FEATURE", "RECALL", "MODEL", "RECALL")
# graph_generator.bar_graph(graph_data, time_path, "FEATURE", "TIME", "MODEL", "TIME")
# Out:
#       cntr          ra        dec             cra            cdec  naxis1  \
# 1166     6   83.376135  22.031351  05h_33m_30.27s  +22d_01m_52.9s     512
# 1489    59   83.631361  21.492451  05h_34m_31.53s  +21d_29m_32.8s     512
# 1116    91   83.248764  21.977989  05h_32m_59.70s  +21d_58m_40.8s     512
# 105     18  229.969665   1.966640  15h_19m_52.72s  +01d_57m_59.9s     512
# 1332    37   84.139640  21.710120  05h_36m_33.51s  +21d_42m_36.4s     512
# 238     27  245.338504 -26.955538  16h_21m_21.24s  -26d_57m_19.9s     512
# 1244    84   83.118935  22.516991  05h_32m_28.54s  +22d_31m_01.2s     512
# 1212    52   83.376205  22.300795  05h_33m_30.29s  +22d_18m_02.9s     512
# 1492    62   83.631562  22.300784  05h_34m_31.57s  +22d_18m_02.8s     512
# 169      0  245.870774 -26.352707  16h_23m_28.99s  -26d_21m_09.7s     512
# 890      0   83.248892  22.247433  05h_32m_59.73s  +22d_14m_50.8s     512
# 172      3  246.003893 -26.420493  16h_24m_00.93s  -26d_25m_13.8s     512
# ...

# %%
import pandas as pd

montage = pd.read_csv('montage.csv', float_precision='round_trip')
columns = ['cntr', 'ra', 'dec', 'cra', 'cdec', 'crval1', 'crval2', 'crota2']
montage = montage[columns]
montage
# Out:
#       cntr          ra        dec             cra            cdec      crval1  \
# 0        0  245.870774 -26.352707  16h_23m_28.99s  -26d_21m_09.7s  245.870619
# 1        1  245.870702 -26.083262  16h_23m_28.97s  -26d_04m_59.7s  245.870548
# 2        2  246.003814 -26.151049  16h_24m_00.92s  -26d_09m_03.8s  246.003659
# 3        3  246.003893 -26.420493  16h_24m_00.93s  -26d_25m_13.8s  246.003738
# 4        4  246.003972 -26.689938  16h_24m_00.95s  -26d_41m_23.8s  246.003817
# 5        5  246.004052 -26.959382  16h_24m_00.97s  -26d_57m_33.8s  246.003896
# 6        6  246.136732 -27.161026  16h_24m_32.82s  -27d_09m_39.7s  246.136576
# 7        7  246.136653 -26.891582  16h_24m_32.80s  -26d_53m_29.7s  246.136497
# 8        8  246.136574 -26.622137  16h_24m_32.78s  -26d_37m_19.7s  246.136419
# 9        9  246.136496 -26.352693  16h_24m_32.76s  -26d_21m_09.7s  246.136341
# 10      10  246.136418 -26.083248  16h_24m_32.74s  -26d_04m_59.7s  246.136264
# ...

# %%
import pandas as pd
data = pd.read_csv('sciphy.csv', float_precision='round_trip')
data = data[~data['erro']].copy().drop('erro', axis=1).reset_index(drop=True)
data.sample(4)
# Out:
#      num_aligns  length   model1        prob1   model2        prob2
# 96         11.0   339.0  WAG+I+F  2012.681247    WAG+I  2052.864650
# 139        10.0   854.0  WAG+I+F  4634.242459  WAG+I+F  4634.242459
# 179        10.0   854.0  WAG+I+F  4634.242459  WAG+I+F  4634.242459
# 295        10.0   237.0    WAG+G  1588.458801    WAG+G  1588.458801
